# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
import os

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import SGD

# from google.colab import drive
# drive.mount('/content/drive')

# CNN MODEL FOR MNIST DATASET
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(10, activation='softmax'))
	opt = SGD(learning_rate=0.01, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

model = define_model()
model.load_weights('mnist_cnn_weights.weights.h5')

from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load the test dataset
(_, _), (testX, testY) = mnist.load_data()

# Reshape the data to have a single channel
testX = testX.reshape((testX.shape[0], 28, 28, 1))

# Normalize the pixel values to the range [0, 1]
testX = testX.astype('float32') / 255.0

# One-hot encode the labels
testY = to_categorical(testY)

# Evaluate the model
# loss, accuracy = model.evaluate(testX, testY, verbose=0)
# print(f'Test accuracy: {accuracy * 100:.2f}%')
# print(f'Test loss: {loss:.4f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
#        0/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 8 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
def get_fx_fxI(f, xs, Is):
  """
  Returns arrays fx and fxI, defined as:
  fx[i]    = f(x),   where x = xs[i]
  fxI[i,j] = f(x-I), where x = xs[i], I = Is[j]
  """
  inputs = []
  for x in xs:
    inputs.append(x)
    for I in Is:
      inputs.append(x-I)
  inputs = np.array(inputs)
  outputs = f(inputs)
  fx = np.ndarray((len(xs),))
  fxI = np.ndarray((len(xs), len(Is)))
  o = 0
  for i in range(len(xs)):
    fx[i] = outputs[o]
    o += 1
    for j in range(len(Is)):
      fxI[i,j] = outputs[o]
      o += 1
  return fx, fxI

# %%
def explain_metrix(fx, fxI, Is, lam, N, K, tol):
  device = 'cuda' if torch.cuda.is_available() else 'cpu'

  int_II = np.array([I @ I.T for I in Is]).mean(axis=0)
  ints_Idf = np.ndarray((N+1, K, 1))
  for i in range(N+1):
    ints_Idf[i] = np.array([I * (fx[i] - fxI[i,j]) for j, I in enumerate(Is)]).mean(axis=0)
  first_mat = np.linalg.inv(lam * N * np.identity(K) + int_II)

  ints_Idf = torch.tensor(ints_Idf, device=device)
  first_mat = torch.tensor(first_mat, device=device)

  phis = torch.zeros(N+1, K, 1, device=device)
  while True:
    phis_prev = phis.clone()
    for n in range(N+1):
      phis_sum = phis.sum(axis=0)
      second_mat = lam * (phis_sum - phis[n]) + ints_Idf[n]
      phis[n] = first_mat @ second_mat
    if torch.abs(phis - phis_prev).max() < tol:
      break

  return np.array(phis.cpu())

# %%
def explain_yeh(fx, fxI, Is, lam, N, K, sigma=None):
  int_II = np.array([I @ I.T for I in Is]).mean(axis=0)
  int_II_inv = np.linalg.inv(int_II)

  phis = np.zeros((N+1, K, 1))
  for i in range(N+1):
    int_Idf = np.array([I * (fx[i] - fxI[i,j]) for j, I in enumerate(Is)]).mean(axis=0)
    phis[i] = int_II_inv @ int_Idf

  # No smoothing
  if sigma is None:
    return phis

  # Apply Gaussian smoothing to the explanations
  smoothed_phis = np.zeros_like(phis)
  for i in range(N+1):
    smoothed_phis[i] = gaussian_filter(phis[i].reshape(28, 28), sigma=sigma).reshape(K, 1)

  return smoothed_phis

# %%
def infidelity(fx, fxI, phi, Is):
  a = [(I.T @ phi - (fx - fxI[j]))**2 for j, I in enumerate(Is)]
  return np.array(a).mean()

def sensitivity(phis):
  phi0 = phis[0]
  return max(((phi-phi0)**2).sum() for phi in phis[1:])

# %%
N = 100
M = 1000
lam = 0
sigma = 5.0
tol = 1e-5

def run_explanations(x):
  np.random.seed(0)
  K = x.shape[0]

  xs = [x]
  for _ in range(N):
    xs.append(x + np.random.normal(size=x.shape, scale=0.2))

  Is = []
  for _ in range(M):
    Is.append(x - np.random.normal(size=x.shape, scale=0.01))

  probs = model.predict(x.reshape(1, 28, 28, 1)).flatten()
  max_class = probs.argmax()
  def fn_mnist(inputs):
    inputs = inputs.reshape(-1, 28, 28, 1)
    probs = model.predict(inputs)
    return probs[:, max_class]

  fx, fxI = get_fx_fxI(fn_mnist, xs, Is)

  return (explain_metrix(fx, fxI, Is, lam, N, K, tol),
          explain_yeh(fx, fxI, Is, lam, N, K, sigma),
          xs, Is, fx, fxI)


def run_range(start, end):
  xes = [testX[i].reshape(784, 1) for i in range(start, end)]

  ours_results = []
  yehs_results = []
  ours_results_infidelity = []
  yehs_results_infidelity = []
  ours_results_sensitivity = []
  yehs_results_sensitivity = []

  for i in range(end-start):
    ours, yehs, cur_xs, cur_Is, fx, fxI = run_explanations(xes[i])
    ours_results.append(ours)
    yehs_results.append(yehs)

    cur_ours_inf = infidelity(fx[0], fxI[0], ours[0], cur_Is)
    cur_yehs_inf = infidelity(fx[0], fxI[0], yehs[0], cur_Is)
    cur_ours_sens = sensitivity(ours)
    cur_yehs_sens = sensitivity(yehs)

    ours_results_infidelity.append(cur_ours_inf)
    yehs_results_infidelity.append(cur_yehs_inf)
    ours_results_sensitivity.append(cur_ours_sens)
    yehs_results_sensitivity.append(cur_yehs_sens)

    if not os.path.exists('output'):
      os.mkdir('output')
    for j in range(N):
      np.save(f'output/image_{i}_perturb_{j}', cur_xs[j].reshape(28, 28))
      np.save(f'output/ours_{i}_perturb_{j}', ours[j].reshape(28, 28))
      np.save(f'output/yehs_{i}_perturb_{j}', yehs[j].reshape(28, 28))

  return (ours_results_infidelity, yehs_results_infidelity,
          ours_results_sensitivity, yehs_results_sensitivity)

results = run_range(0, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step

# %%
lams = [0, 1e-5, 1e-4, 5e-4, 2e-3, 5e-3, 1e-2]
results_all = []
for lam in lams:
  results_all.append(run_range(0, 5))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3160/3160 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step

# %%
lams_str = ['0', '$1 \cdot 10^{-5}$', '$1 \cdot 10^{-4}$', '$5 \cdot 10^{-4}$',
            '$2 \cdot 10^{-3}$', '$5 \cdot 10^{-3}$', '$1 \cdot 10^{-2}$']
fig, ax = plt.subplots(5, 2, figsize=(10,10))
for pt in range(5):
  ax[pt][0].plot(lams_str, [results_all[i][0][pt] for i in range(7)], marker='o')
  ax[pt][0].set_ylabel('Infidelity')
  ax[pt][0].set_title(f'Infidelity vs. $\lambda$, image {pt+1}')
ax[4][0].set_xlabel('$\lambda$')
for pt in range(5):
  ax[pt][1].plot(lams_str, [results_all[i][2][pt] for i in range(7)], marker='o')
  ax[pt][1].set_yscale('log')
  ax[pt][1].set_ylabel('Sensitivity')
  ax[pt][1].set_title(f'Sensitivity vs. $\lambda$, image {pt+1}')
ax[4][1].set_xlabel('$\lambda$')
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-08ac3bcc3301> in <cell line: 4>()
#       3 fig, ax = plt.subplots(5, 2, figsize=(10,10))
#       4 for pt in range(5):
# ----> 5   ax[pt][0].plot(lams_str, [results_all[i][0][pt] for i in range(7)], marker='o')
#       6   ax[pt][0].set_ylabel('Infidelity')
#       7   ax[pt][0].set_title(f'Infidelity vs. $\lambda$, image {pt+1}')
#
# <ipython-input-34-08ac3bcc3301> in <listcomp>(.0)
#       3 fig, ax = plt.subplots(5, 2, figsize=(10,10))
#       4 for pt in range(5):
# ----> 5   ax[pt][0].plot(lams_str, [results_all[i][0][pt] for i in range(7)], marker='o')
#       6   ax[pt][0].set_ylabel('Infidelity')
#       7   ax[pt][0].set_title(f'Infidelity vs. $\lambda$, image {pt+1}')
#
# NameError: name 'results_all' is not defined

# %%
for res in results:
  print(res)
# Out:
# [2.719156112236556e-05, 1.1496742702635146e-05, 1.0465307303812706e-05, 1.8567301535630098e-06, 3.2040081534289527e-06]
# [1.7536304422799157e-06, 1.0339347400172058e-06, 1.6578421871894904e-06, 3.563925671709171e-07, 7.280527098152852e-07]
# [0.0027308469, 0.00024255074, 0.001675606, 5.3526564e-05, 0.0001293525]
# [3.868551497832557, 2.56148473375612, 1.631988953213734, 0.059909158458034795, 0.1765386414826387]

# %%
# !zip -r /content/output.zip /content/output
# Out:
# updating: content/output/ (stored 0%)
# updating: content/output/ours_3_perturb_45.npy (deflated 7%)
# updating: content/output/ours_1_perturb_46.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_13.npy (deflated 29%)
# updating: content/output/ours_3_perturb_26.npy (deflated 7%)
# updating: content/output/ours_4_perturb_28.npy (deflated 7%)
# updating: content/output/ours_4_perturb_43.npy (deflated 6%)
# updating: content/output/yehs_4_perturb_28.npy (deflated 26%)
# updating: content/output/image_1_perturb_22.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_0.npy (deflated 27%)
# updating: content/output/ours_3_perturb_39.npy (deflated 7%)
# updating: content/output/image_0_perturb_47.npy (deflated 5%)
# updating: content/output/image_3_perturb_37.npy (deflated 5%)
# updating: content/output/ours_2_perturb_14.npy (deflated 7%)
# updating: content/output/ours_3_perturb_3.npy (deflated 7%)
# updating: content/output/image_2_perturb_22.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_9.npy (deflated 24%)
# updating: content/output/yehs_4_perturb_32.npy (deflated 27%)
# updating: content/output/yehs_0_perturb_38.npy (deflated 27%)
# updating: content/output/yehs_0_perturb_22.npy (deflated 25%)
# updating: content/output/image_1_perturb_39.npy (deflated 5%)
# updating: content/output/image_2_perturb_30.npy (deflated 5%)
# updating: content/output/ours_0_perturb_12.npy (deflated 8%)
# updating: content/output/ours_4_perturb_30.npy (deflated 7%)
# updating: content/output/ours_3_perturb_28.npy (deflated 7%)
# updating: content/output/image_3_perturb_38.npy (deflated 5%)
# updating: content/output/image_2_perturb_18.npy (deflated 5%)
# updating: content/output/ours_2_perturb_33.npy (deflated 7%)
# updating: content/output/image_4_perturb_13.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_11.npy (deflated 27%)
# updating: content/output/ours_2_perturb_34.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_42.npy (deflated 27%)
# updating: content/output/yehs_2_perturb_33.npy (deflated 26%)
# updating: content/output/ours_0_perturb_20.npy (deflated 7%)
# updating: content/output/ours_2_perturb_12.npy (deflated 7%)
# updating: content/output/image_2_perturb_29.npy (deflated 5%)
# updating: content/output/ours_4_perturb_39.npy (deflated 6%)
# updating: content/output/ours_4_perturb_15.npy (deflated 6%)
# updating: content/output/image_1_perturb_45.npy (deflated 4%)
# updating: content/output/yehs_2_perturb_47.npy (deflated 24%)
# updating: content/output/ours_2_perturb_48.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_43.npy (deflated 29%)
# updating: content/output/ours_1_perturb_34.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_13.npy (deflated 27%)
# updating: content/output/image_1_perturb_23.npy (deflated 5%)
# updating: content/output/ours_2_perturb_21.npy (deflated 7%)
# updating: content/output/ours_2_perturb_30.npy (deflated 7%)
# updating: content/output/ours_0_perturb_39.npy (deflated 8%)
# updating: content/output/yehs_0_perturb_48.npy (deflated 24%)
# updating: content/output/ours_3_perturb_23.npy (deflated 7%)
# updating: content/output/image_2_perturb_26.npy (deflated 5%)
# updating: content/output/ours_3_perturb_21.npy (deflated 7%)
# updating: content/output/ours_3_perturb_10.npy (deflated 7%)
# updating: content/output/image_4_perturb_24.npy (deflated 4%)
# updating: content/output/ours_1_perturb_21.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_28.npy (deflated 24%)
# updating: content/output/yehs_1_perturb_47.npy (deflated 25%)
# updating: content/output/yehs_3_perturb_46.npy (deflated 28%)
# updating: content/output/ours_2_perturb_41.npy (deflated 7%)
# updating: content/output/ours_4_perturb_2.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_7.npy (deflated 25%)
# updating: content/output/yehs_0_perturb_26.npy (deflated 24%)
# updating: content/output/ours_2_perturb_24.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_47.npy (deflated 26%)
# updating: content/output/image_0_perturb_35.npy (deflated 5%)
# updating: content/output/image_3_perturb_3.npy (deflated 5%)
# updating: content/output/image_2_perturb_1.npy (deflated 5%)
# updating: content/output/ours_4_perturb_29.npy (deflated 6%)
# updating: content/output/yehs_1_perturb_10.npy (deflated 28%)
# updating: content/output/image_1_perturb_30.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_39.npy (deflated 29%)
# updating: content/output/image_0_perturb_44.npy (deflated 5%)
# updating: content/output/image_4_perturb_41.npy (deflated 5%)
# updating: content/output/image_2_perturb_49.npy (deflated 5%)
# updating: content/output/image_1_perturb_6.npy (deflated 5%)
# updating: content/output/ours_1_perturb_14.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_15.npy (deflated 24%)
# updating: content/output/yehs_1_perturb_39.npy (deflated 27%)
# updating: content/output/image_0_perturb_46.npy (deflated 5%)
# updating: content/output/ours_1_perturb_43.npy (deflated 7%)
# updating: content/output/image_3_perturb_28.npy (deflated 4%)
# updating: content/output/image_2_perturb_19.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_7.npy (deflated 29%)
# updating: content/output/image_0_perturb_20.npy (deflated 4%)
# updating: content/output/yehs_1_perturb_25.npy (deflated 28%)
# updating: content/output/yehs_3_perturb_1.npy (deflated 29%)
# updating: content/output/ours_3_perturb_44.npy (deflated 7%)
# updating: content/output/image_1_perturb_40.npy (deflated 5%)
# updating: content/output/ours_2_perturb_49.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_10.npy (deflated 29%)
# updating: content/output/image_4_perturb_11.npy (deflated 4%)
# updating: content/output/yehs_2_perturb_14.npy (deflated 25%)
# updating: content/output/image_4_perturb_27.npy (deflated 5%)
# updating: content/output/ours_3_perturb_7.npy (deflated 7%)
# updating: content/output/image_1_perturb_27.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_36.npy (deflated 29%)
# updating: content/output/ours_1_perturb_37.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_34.npy (deflated 24%)
# updating: content/output/ours_3_perturb_38.npy (deflated 6%)
# updating: content/output/yehs_3_perturb_18.npy (deflated 29%)
# updating: content/output/yehs_0_perturb_30.npy (deflated 26%)
# updating: content/output/ours_3_perturb_41.npy (deflated 7%)
# updating: content/output/ours_4_perturb_25.npy (deflated 6%)
# updating: content/output/ours_3_perturb_18.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_29.npy (deflated 26%)
# updating: content/output/yehs_1_perturb_7.npy (deflated 27%)
# updating: content/output/ours_2_perturb_43.npy (deflated 7%)
# updating: content/output/ours_3_perturb_37.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_27.npy (deflated 26%)
# updating: content/output/ours_1_perturb_5.npy (deflated 7%)
# updating: content/output/image_3_perturb_46.npy (deflated 5%)
# updating: content/output/image_0_perturb_30.npy (deflated 5%)
# updating: content/output/ours_0_perturb_13.npy (deflated 7%)
# updating: content/output/image_4_perturb_10.npy (deflated 5%)
# updating: content/output/image_4_perturb_6.npy (deflated 5%)
# updating: content/output/ours_3_perturb_32.npy (deflated 7%)
# updating: content/output/ours_1_perturb_26.npy (deflated 7%)
# updating: content/output/image_0_perturb_31.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_17.npy (deflated 24%)
# updating: content/output/ours_4_perturb_36.npy (deflated 7%)
# updating: content/output/ours_3_perturb_36.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_10.npy (deflated 25%)
# updating: content/output/ours_3_perturb_49.npy (deflated 7%)
# updating: content/output/ours_1_perturb_32.npy (deflated 7%)
# updating: content/output/ours_4_perturb_44.npy (deflated 6%)
# updating: content/output/yehs_3_perturb_29.npy (deflated 28%)
# updating: content/output/image_2_perturb_9.npy (deflated 4%)
# updating: content/output/ours_1_perturb_18.npy (deflated 7%)
# updating: content/output/image_2_perturb_41.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_49.npy (deflated 29%)
# updating: content/output/ours_0_perturb_31.npy (deflated 8%)
# updating: content/output/yehs_4_perturb_20.npy (deflated 27%)
# updating: content/output/yehs_2_perturb_36.npy (deflated 24%)
# updating: content/output/yehs_4_perturb_24.npy (deflated 27%)
# updating: content/output/ours_2_perturb_19.npy (deflated 7%)
# updating: content/output/ours_4_perturb_27.npy (deflated 6%)
# updating: content/output/yehs_1_perturb_2.npy (deflated 24%)
# updating: content/output/image_2_perturb_8.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_1.npy (deflated 25%)
# updating: content/output/yehs_1_perturb_4.npy (deflated 28%)
# updating: content/output/yehs_2_perturb_46.npy (deflated 21%)
# updating: content/output/yehs_1_perturb_43.npy (deflated 26%)
# updating: content/output/yehs_2_perturb_44.npy (deflated 25%)
# updating: content/output/image_1_perturb_36.npy (deflated 5%)
# updating: content/output/ours_3_perturb_33.npy (deflated 6%)
# updating: content/output/image_1_perturb_33.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_38.npy (deflated 29%)
# updating: content/output/image_0_perturb_0.npy (deflated 86%)
# updating: content/output/yehs_3_perturb_0.npy (deflated 27%)
# updating: content/output/image_4_perturb_8.npy (deflated 5%)
# updating: content/output/image_2_perturb_4.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_44.npy (deflated 24%)
# updating: content/output/ours_4_perturb_35.npy (deflated 6%)
# updating: content/output/yehs_0_perturb_7.npy (deflated 23%)
# updating: content/output/ours_2_perturb_7.npy (deflated 7%)
# updating: content/output/ours_4_perturb_42.npy (deflated 6%)
# updating: content/output/image_3_perturb_5.npy (deflated 4%)
# updating: content/output/ours_0_perturb_48.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_6.npy (deflated 27%)
# updating: content/output/ours_4_perturb_13.npy (deflated 6%)
# updating: content/output/yehs_1_perturb_34.npy (deflated 26%)
# updating: content/output/ours_3_perturb_6.npy (deflated 7%)
# updating: content/output/ours_1_perturb_36.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_8.npy (deflated 24%)
# updating: content/output/yehs_1_perturb_13.npy (deflated 28%)
# updating: content/output/ours_2_perturb_4.npy (deflated 7%)
# updating: content/output/ours_0_perturb_36.npy (deflated 7%)
# updating: content/output/image_3_perturb_14.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_11.npy (deflated 27%)
# updating: content/output/image_0_perturb_48.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_34.npy (deflated 25%)
# updating: content/output/image_1_perturb_9.npy (deflated 5%)
# updating: content/output/image_0_perturb_28.npy (deflated 4%)
# updating: content/output/ours_3_perturb_13.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_29.npy (deflated 22%)
# updating: content/output/image_2_perturb_12.npy (deflated 5%)
# updating: content/output/ours_2_perturb_3.npy (deflated 7%)
# updating: content/output/ours_2_perturb_26.npy (deflated 7%)
# updating: content/output/ours_3_perturb_35.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_43.npy (deflated 22%)
# updating: content/output/ours_2_perturb_13.npy (deflated 7%)
# updating: content/output/image_3_perturb_36.npy (deflated 5%)
# updating: content/output/image_3_perturb_31.npy (deflated 5%)
# updating: content/output/ours_0_perturb_8.npy (deflated 7%)
# updating: content/output/ours_3_perturb_48.npy (deflated 7%)
# updating: content/output/ours_4_perturb_4.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_26.npy (deflated 29%)
# updating: content/output/ours_2_perturb_46.npy (deflated 7%)
# updating: content/output/ours_0_perturb_14.npy (deflated 7%)
# updating: content/output/image_1_perturb_46.npy (deflated 5%)
# updating: content/output/ours_3_perturb_9.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_21.npy (deflated 27%)
# updating: content/output/image_4_perturb_20.npy (deflated 5%)
# updating: content/output/ours_4_perturb_49.npy (deflated 6%)
# updating: content/output/ours_1_perturb_15.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_3.npy (deflated 26%)
# updating: content/output/image_2_perturb_2.npy (deflated 5%)
# updating: content/output/ours_2_perturb_0.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_45.npy (deflated 26%)
# updating: content/output/ours_0_perturb_37.npy (deflated 8%)
# updating: content/output/image_0_perturb_42.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_35.npy (deflated 28%)
# updating: content/output/yehs_1_perturb_33.npy (deflated 24%)
# updating: content/output/ours_2_perturb_15.npy (deflated 7%)
# updating: content/output/yehs_1_perturb_3.npy (deflated 25%)
# updating: content/output/image_0_perturb_11.npy (deflated 4%)
# updating: content/output/ours_4_perturb_7.npy (deflated 7%)
# updating: content/output/ours_1_perturb_24.npy (deflated 7%)
# updating: content/output/ours_1_perturb_28.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_30.npy (deflated 29%)
# updating: content/output/yehs_0_perturb_33.npy (deflated 26%)
# updating: content/output/image_1_perturb_11.npy (deflated 4%)
# updating: content/output/yehs_4_perturb_38.npy (deflated 27%)
# updating: content/output/yehs_0_perturb_43.npy (deflated 24%)
# updating: content/output/yehs_4_perturb_30.npy (deflated 27%)
# updating: content/output/ours_3_perturb_42.npy (deflated 6%)
# updating: content/output/image_3_perturb_9.npy (deflated 4%)
# updating: content/output/image_0_perturb_49.npy (deflated 5%)
# updating: content/output/ours_2_perturb_45.npy (deflated 7%)
# updating: content/output/yehs_1_perturb_40.npy (deflated 25%)
# updating: content/output/yehs_4_perturb_25.npy (deflated 27%)
# updating: content/output/ours_2_perturb_27.npy (deflated 7%)
# updating: content/output/ours_0_perturb_30.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_22.npy (deflated 29%)
# updating: content/output/image_3_perturb_6.npy (deflated 4%)
# updating: content/output/image_1_perturb_2.npy (deflated 5%)
# updating: content/output/ours_4_perturb_8.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_27.npy (deflated 25%)
# updating: content/output/image_2_perturb_37.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_25.npy (deflated 25%)
# updating: content/output/ours_2_perturb_16.npy (deflated 7%)
# updating: content/output/ours_3_perturb_29.npy (deflated 7%)
# updating: content/output/image_2_perturb_28.npy (deflated 4%)
# updating: content/output/yehs_1_perturb_49.npy (deflated 26%)
# updating: content/output/image_1_perturb_47.npy (deflated 5%)
# updating: content/output/image_2_perturb_10.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_44.npy (deflated 29%)
# updating: content/output/image_0_perturb_41.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_27.npy (deflated 24%)
# updating: content/output/image_3_perturb_15.npy (deflated 4%)
# updating: content/output/image_4_perturb_26.npy (deflated 5%)
# updating: content/output/image_0_perturb_33.npy (deflated 5%)
# updating: content/output/ours_0_perturb_44.npy (deflated 8%)
# updating: content/output/image_2_perturb_43.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_42.npy (deflated 27%)
# updating: content/output/image_3_perturb_7.npy (deflated 5%)
# updating: content/output/ours_0_perturb_42.npy (deflated 8%)
# updating: content/output/ours_1_perturb_40.npy (deflated 7%)
# updating: content/output/ours_2_perturb_28.npy (deflated 7%)
# updating: content/output/image_3_perturb_45.npy (deflated 4%)
# updating: content/output/image_0_perturb_24.npy (deflated 5%)
# updating: content/output/image_2_perturb_14.npy (deflated 5%)
# updating: content/output/ours_1_perturb_17.npy (deflated 7%)
# updating: content/output/image_0_perturb_32.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_15.npy (deflated 24%)
# updating: content/output/ours_1_perturb_38.npy (deflated 7%)
# updating: content/output/ours_2_perturb_36.npy (deflated 7%)
# updating: content/output/image_1_perturb_34.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_7.npy (deflated 27%)
# updating: content/output/ours_0_perturb_16.npy (deflated 8%)
# updating: content/output/image_4_perturb_40.npy (deflated 5%)
# updating: content/output/ours_4_perturb_14.npy (deflated 6%)
# updating: content/output/yehs_2_perturb_49.npy (deflated 24%)
# updating: content/output/yehs_0_perturb_17.npy (deflated 25%)
# updating: content/output/yehs_4_perturb_1.npy (deflated 27%)
# updating: content/output/ours_0_perturb_4.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_14.npy (deflated 27%)
# updating: content/output/ours_3_perturb_5.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_31.npy (deflated 27%)
# updating: content/output/ours_2_perturb_38.npy (deflated 7%)
# updating: content/output/image_4_perturb_22.npy (deflated 4%)
# updating: content/output/yehs_1_perturb_16.npy (deflated 28%)
# updating: content/output/yehs_0_perturb_36.npy (deflated 23%)
# updating: content/output/yehs_1_perturb_21.npy (deflated 26%)
# updating: content/output/yehs_1_perturb_24.npy (deflated 27%)
# updating: content/output/ours_0_perturb_11.npy (deflated 7%)
# updating: content/output/yehs_1_perturb_14.npy (deflated 26%)
# updating: content/output/image_2_perturb_0.npy (deflated 89%)
# updating: content/output/yehs_1_perturb_30.npy (deflated 27%)
# updating: content/output/image_3_perturb_32.npy (deflated 5%)
# updating: content/output/ours_2_perturb_1.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_4.npy (deflated 26%)
# updating: content/output/yehs_2_perturb_12.npy (deflated 25%)
# updating: content/output/image_2_perturb_11.npy (deflated 5%)
# updating: content/output/ours_1_perturb_11.npy (deflated 7%)
# updating: content/output/ours_0_perturb_49.npy (deflated 7%)
# updating: content/output/ours_1_perturb_42.npy (deflated 7%)
# updating: content/output/image_3_perturb_26.npy (deflated 5%)
# updating: content/output/ours_0_perturb_34.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_18.npy (deflated 24%)
# updating: content/output/yehs_2_perturb_25.npy (deflated 25%)
# updating: content/output/image_2_perturb_3.npy (deflated 5%)
# updating: content/output/image_0_perturb_10.npy (deflated 5%)
# updating: content/output/ours_0_perturb_38.npy (deflated 7%)
# updating: content/output/ours_4_perturb_24.npy (deflated 6%)
# updating: content/output/ours_1_perturb_33.npy (deflated 7%)
# updating: content/output/image_4_perturb_1.npy (deflated 5%)
# updating: content/output/image_0_perturb_23.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_11.npy (deflated 25%)
# updating: content/output/yehs_1_perturb_17.npy (deflated 24%)
# updating: content/output/ours_0_perturb_29.npy (deflated 8%)
# updating: content/output/yehs_0_perturb_35.npy (deflated 24%)
# updating: content/output/image_0_perturb_38.npy (deflated 5%)
# updating: content/output/ours_4_perturb_33.npy (deflated 6%)
# updating: content/output/image_3_perturb_48.npy (deflated 4%)
# updating: content/output/ours_3_perturb_40.npy (deflated 7%)
# updating: content/output/image_0_perturb_19.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_31.npy (deflated 26%)
# updating: content/output/image_1_perturb_42.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_32.npy (deflated 29%)
# updating: content/output/ours_1_perturb_13.npy (deflated 7%)
# updating: content/output/ours_2_perturb_18.npy (deflated 7%)
# updating: content/output/ours_1_perturb_39.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_32.npy (deflated 24%)
# updating: content/output/yehs_0_perturb_9.npy (deflated 23%)
# updating: content/output/ours_1_perturb_27.npy (deflated 7%)
# updating: content/output/image_4_perturb_12.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_17.npy (deflated 29%)
# updating: content/output/image_0_perturb_26.npy (deflated 5%)
# updating: content/output/image_1_perturb_5.npy (deflated 5%)
# updating: content/output/image_4_perturb_16.npy (deflated 4%)
# updating: content/output/image_0_perturb_5.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_16.npy (deflated 25%)
# updating: content/output/ours_1_perturb_3.npy (deflated 7%)
# updating: content/output/yehs_1_perturb_45.npy (deflated 28%)
# updating: content/output/yehs_3_perturb_15.npy (deflated 29%)
# updating: content/output/ours_1_perturb_16.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_41.npy (deflated 29%)
# updating: content/output/ours_3_perturb_16.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_46.npy (deflated 25%)
# updating: content/output/ours_3_perturb_30.npy (deflated 7%)
# updating: content/output/ours_1_perturb_23.npy (deflated 7%)
# updating: content/output/ours_3_perturb_17.npy (deflated 7%)
# updating: content/output/yehs_1_perturb_22.npy (deflated 26%)
# updating: content/output/image_1_perturb_3.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_2.npy (deflated 27%)
# updating: content/output/image_4_perturb_47.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_27.npy (deflated 29%)
# updating: content/output/yehs_4_perturb_17.npy (deflated 26%)
# updating: content/output/yehs_0_perturb_10.npy (deflated 24%)
# updating: content/output/image_3_perturb_29.npy (deflated 5%)
# updating: content/output/image_1_perturb_10.npy (deflated 5%)
# updating: content/output/ours_0_perturb_43.npy (deflated 7%)
# updating: content/output/image_1_perturb_29.npy (deflated 5%)
# updating: content/output/ours_3_perturb_2.npy (deflated 7%)
# updating: content/output/ours_4_perturb_26.npy (deflated 6%)
# updating: content/output/image_4_perturb_33.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_10.npy (deflated 27%)
# updating: content/output/yehs_3_perturb_4.npy (deflated 29%)
# updating: content/output/ours_4_perturb_48.npy (deflated 6%)
# updating: content/output/ours_1_perturb_41.npy (deflated 7%)
# updating: content/output/ours_0_perturb_22.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_20.npy (deflated 25%)
# updating: content/output/ours_4_perturb_22.npy (deflated 6%)
# updating: content/output/yehs_3_perturb_31.npy (deflated 29%)
# updating: content/output/image_2_perturb_7.npy (deflated 5%)
# updating: content/output/image_2_perturb_20.npy (deflated 4%)
# updating: content/output/yehs_1_perturb_36.npy (deflated 27%)
# updating: content/output/image_2_perturb_35.npy (deflated 4%)
# updating: content/output/ours_2_perturb_10.npy (deflated 7%)
# updating: content/output/image_4_perturb_34.npy (deflated 5%)
# updating: content/output/ours_0_perturb_19.npy (deflated 7%)
# updating: content/output/ours_2_perturb_37.npy (deflated 7%)
# updating: content/output/image_4_perturb_9.npy (deflated 4%)
# updating: content/output/ours_2_perturb_5.npy (deflated 7%)
# updating: content/output/image_3_perturb_27.npy (deflated 5%)
# updating: content/output/image_4_perturb_46.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_28.npy (deflated 22%)
# updating: content/output/ours_0_perturb_41.npy (deflated 8%)
# updating: content/output/image_4_perturb_19.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_1.npy (deflated 22%)
# updating: content/output/image_0_perturb_9.npy (deflated 4%)
# updating: content/output/image_4_perturb_18.npy (deflated 4%)
# updating: content/output/yehs_4_perturb_23.npy (deflated 27%)
# updating: content/output/ours_3_perturb_11.npy (deflated 7%)
# updating: content/output/image_0_perturb_27.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_38.npy (deflated 28%)
# updating: content/output/ours_1_perturb_47.npy (deflated 7%)
# updating: content/output/ours_1_perturb_35.npy (deflated 7%)
# updating: content/output/ours_3_perturb_43.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_35.npy (deflated 29%)
# updating: content/output/image_0_perturb_15.npy (deflated 4%)
# updating: content/output/yehs_4_perturb_33.npy (deflated 27%)
# updating: content/output/image_2_perturb_45.npy (deflated 5%)
# updating: content/output/image_1_perturb_18.npy (deflated 5%)
# updating: content/output/image_0_perturb_18.npy (deflated 5%)
# updating: content/output/ours_2_perturb_47.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_21.npy (deflated 24%)
# updating: content/output/yehs_4_perturb_46.npy (deflated 27%)
# updating: content/output/ours_0_perturb_26.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_34.npy (deflated 29%)
# updating: content/output/ours_2_perturb_40.npy (deflated 7%)
# updating: content/output/ours_4_perturb_5.npy (deflated 7%)
# updating: content/output/ours_3_perturb_34.npy (deflated 6%)
# updating: content/output/yehs_3_perturb_16.npy (deflated 29%)
# updating: content/output/yehs_2_perturb_6.npy (deflated 25%)
# updating: content/output/yehs_4_perturb_4.npy (deflated 27%)
# updating: content/output/yehs_4_perturb_48.npy (deflated 27%)
# updating: content/output/ours_0_perturb_2.npy (deflated 7%)
# updating: content/output/image_0_perturb_36.npy (deflated 5%)
# updating: content/output/ours_2_perturb_25.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_21.npy (deflated 29%)
# updating: content/output/image_0_perturb_3.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_30.npy (deflated 25%)
# updating: content/output/ours_4_perturb_6.npy (deflated 7%)
# updating: content/output/image_2_perturb_25.npy (deflated 5%)
# updating: content/output/image_1_perturb_16.npy (deflated 4%)
# updating: content/output/image_4_perturb_45.npy (deflated 4%)
# updating: content/output/ours_4_perturb_23.npy (deflated 6%)
# updating: content/output/image_1_perturb_25.npy (deflated 5%)
# updating: content/output/image_1_perturb_31.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_42.npy (deflated 25%)
# updating: content/output/ours_1_perturb_48.npy (deflated 7%)
# updating: content/output/ours_4_perturb_40.npy (deflated 6%)
# updating: content/output/yehs_1_perturb_8.npy (deflated 25%)
# updating: content/output/yehs_2_perturb_21.npy (deflated 23%)
# updating: content/output/image_0_perturb_6.npy (deflated 5%)
# updating: content/output/ours_3_perturb_4.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_0.npy (deflated 26%)
# updating: content/output/yehs_3_perturb_6.npy (deflated 29%)
# updating: content/output/yehs_3_perturb_12.npy (deflated 29%)
# updating: content/output/yehs_4_perturb_22.npy (deflated 27%)
# updating: content/output/yehs_3_perturb_33.npy (deflated 29%)
# updating: content/output/yehs_4_perturb_39.npy (deflated 27%)
# updating: content/output/yehs_2_perturb_2.npy (deflated 24%)
# updating: content/output/ours_2_perturb_9.npy (deflated 7%)
# updating: content/output/image_4_perturb_42.npy (deflated 4%)
# updating: content/output/ours_4_perturb_31.npy (deflated 6%)
# updating: content/output/ours_2_perturb_6.npy (deflated 7%)
# updating: content/output/ours_0_perturb_40.npy (deflated 7%)
# updating: content/output/ours_1_perturb_2.npy (deflated 7%)
# updating: content/output/ours_0_perturb_24.npy (deflated 7%)
# updating: content/output/image_4_perturb_36.npy (deflated 5%)
# updating: content/output/ours_1_perturb_4.npy (deflated 7%)
# updating: content/output/image_1_perturb_0.npy (deflated 85%)
# updating: content/output/image_0_perturb_22.npy (deflated 5%)
# updating: content/output/ours_3_perturb_19.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_2.npy (deflated 29%)
# updating: content/output/image_4_perturb_7.npy (deflated 4%)
# updating: content/output/image_0_perturb_16.npy (deflated 5%)
# updating: content/output/ours_1_perturb_9.npy (deflated 7%)
# updating: content/output/image_1_perturb_43.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_5.npy (deflated 28%)
# updating: content/output/ours_4_perturb_12.npy (deflated 6%)
# updating: content/output/image_1_perturb_48.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_24.npy (deflated 24%)
# updating: content/output/yehs_1_perturb_27.npy (deflated 27%)
# updating: content/output/ours_3_perturb_8.npy (deflated 7%)
# updating: content/output/ours_3_perturb_15.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_44.npy (deflated 27%)
# updating: content/output/image_2_perturb_13.npy (deflated 5%)
# updating: content/output/ours_1_perturb_44.npy (deflated 7%)
# updating: content/output/image_3_perturb_44.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_29.npy (deflated 26%)
# updating: content/output/image_1_perturb_32.npy (deflated 5%)
# updating: content/output/image_3_perturb_12.npy (deflated 5%)
# updating: content/output/image_3_perturb_22.npy (deflated 4%)
# updating: content/output/ours_3_perturb_24.npy (deflated 7%)
# updating: content/output/ours_2_perturb_42.npy (deflated 7%)
# updating: content/output/ours_0_perturb_1.npy (deflated 7%)
# updating: content/output/ours_0_perturb_7.npy (deflated 7%)
# updating: content/output/yehs_1_perturb_44.npy (deflated 26%)
# updating: content/output/yehs_0_perturb_31.npy (deflated 24%)
# updating: content/output/yehs_2_perturb_22.npy (deflated 25%)
# updating: content/output/yehs_3_perturb_25.npy (deflated 29%)
# updating: content/output/image_1_perturb_12.npy (deflated 5%)
# updating: content/output/ours_4_perturb_11.npy (deflated 6%)
# updating: content/output/yehs_1_perturb_32.npy (deflated 28%)
# updating: content/output/image_0_perturb_14.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_18.npy (deflated 27%)
# updating: content/output/yehs_0_perturb_20.npy (deflated 23%)
# updating: content/output/image_4_perturb_30.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_14.npy (deflated 24%)
# updating: content/output/yehs_1_perturb_1.npy (deflated 26%)
# updating: content/output/yehs_4_perturb_5.npy (deflated 27%)
# updating: content/output/image_0_perturb_29.npy (deflated 5%)
# updating: content/output/ours_2_perturb_2.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_28.npy (deflated 29%)
# updating: content/output/yehs_0_perturb_16.npy (deflated 25%)
# updating: content/output/yehs_0_perturb_3.npy (deflated 23%)
# updating: content/output/ours_4_perturb_46.npy (deflated 6%)
# updating: content/output/image_3_perturb_25.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_13.npy (deflated 21%)
# updating: content/output/ours_3_perturb_27.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_8.npy (deflated 23%)
# updating: content/output/image_4_perturb_28.npy (deflated 4%)
# updating: content/output/image_1_perturb_24.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_9.npy (deflated 26%)
# updating: content/output/image_2_perturb_34.npy (deflated 5%)
# updating: content/output/image_3_perturb_8.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_43.npy (deflated 26%)
# updating: content/output/image_3_perturb_24.npy (deflated 4%)
# updating: content/output/yehs_0_perturb_32.npy (deflated 25%)
# updating: content/output/ours_1_perturb_29.npy (deflated 7%)
# updating: content/output/image_0_perturb_21.npy (deflated 4%)
# updating: content/output/yehs_0_perturb_5.npy (deflated 24%)
# updating: content/output/image_1_perturb_35.npy (deflated 4%)
# updating: content/output/image_0_perturb_43.npy (deflated 5%)
# updating: content/output/image_2_perturb_15.npy (deflated 5%)
# updating: content/output/ours_0_perturb_35.npy (deflated 7%)
# updating: content/output/ours_1_perturb_45.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_15.npy (deflated 27%)
# updating: content/output/ours_4_perturb_20.npy (deflated 7%)
# updating: content/output/yehs_1_perturb_6.npy (deflated 25%)
# updating: content/output/ours_3_perturb_0.npy (deflated 7%)
# updating: content/output/image_2_perturb_38.npy (deflated 5%)
# updating: content/output/image_3_perturb_42.npy (deflated 5%)
# updating: content/output/ours_2_perturb_20.npy (deflated 7%)
# updating: content/output/ours_4_perturb_37.npy (deflated 6%)
# updating: content/output/yehs_1_perturb_20.npy (deflated 26%)
# updating: content/output/image_3_perturb_19.npy (deflated 4%)
# updating: content/output/image_2_perturb_21.npy (deflated 5%)
# updating: content/output/image_4_perturb_2.npy (deflated 5%)
# updating: content/output/ours_4_perturb_18.npy (deflated 6%)
# updating: content/output/ours_4_perturb_17.npy (deflated 6%)
# updating: content/output/image_0_perturb_1.npy (deflated 5%)
# updating: content/output/ours_4_perturb_45.npy (deflated 6%)
# updating: content/output/ours_0_perturb_0.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_19.npy (deflated 27%)
# updating: content/output/yehs_2_perturb_45.npy (deflated 22%)
# updating: content/output/ours_0_perturb_15.npy (deflated 8%)
# updating: content/output/ours_2_perturb_35.npy (deflated 7%)
# updating: content/output/ours_1_perturb_6.npy (deflated 7%)
# updating: content/output/image_1_perturb_1.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_5.npy (deflated 24%)
# updating: content/output/ours_2_perturb_32.npy (deflated 7%)
# updating: content/output/ours_2_perturb_39.npy (deflated 7%)
# updating: content/output/ours_1_perturb_30.npy (deflated 7%)
# updating: content/output/image_2_perturb_39.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_20.npy (deflated 29%)
# updating: content/output/yehs_0_perturb_47.npy (deflated 24%)
# updating: content/output/yehs_2_perturb_13.npy (deflated 25%)
# updating: content/output/yehs_4_perturb_9.npy (deflated 27%)
# updating: content/output/image_1_perturb_28.npy (deflated 4%)
# updating: content/output/yehs_0_perturb_11.npy (deflated 22%)
# updating: content/output/image_3_perturb_39.npy (deflated 4%)
# updating: content/output/ours_3_perturb_14.npy (deflated 7%)
# updating: content/output/image_4_perturb_31.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_18.npy (deflated 24%)
# updating: content/output/image_4_perturb_23.npy (deflated 5%)
# updating: content/output/image_1_perturb_21.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_19.npy (deflated 25%)
# updating: content/output/yehs_3_perturb_47.npy (deflated 29%)
# updating: content/output/ours_0_perturb_10.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_37.npy (deflated 29%)
# updating: content/output/yehs_2_perturb_23.npy (deflated 24%)
# updating: content/output/yehs_4_perturb_37.npy (deflated 27%)
# updating: content/output/ours_0_perturb_5.npy (deflated 7%)
# updating: content/output/image_4_perturb_29.npy (deflated 5%)
# updating: content/output/image_0_perturb_39.npy (deflated 4%)
# updating: content/output/yehs_0_perturb_12.npy (deflated 23%)
# updating: content/output/yehs_1_perturb_23.npy (deflated 24%)
# updating: content/output/image_0_perturb_45.npy (deflated 5%)
# updating: content/output/ours_2_perturb_22.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_40.npy (deflated 24%)
# updating: content/output/ours_2_perturb_8.npy (deflated 7%)
# updating: content/output/ours_2_perturb_29.npy (deflated 7%)
# updating: content/output/image_3_perturb_17.npy (deflated 4%)
# updating: content/output/ours_2_perturb_44.npy (deflated 7%)
# updating: content/output/ours_1_perturb_10.npy (deflated 7%)
# updating: content/output/ours_2_perturb_11.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_19.npy (deflated 29%)
# updating: content/output/image_3_perturb_16.npy (deflated 5%)
# updating: content/output/image_4_perturb_25.npy (deflated 5%)
# updating: content/output/ours_0_perturb_33.npy (deflated 7%)
# updating: content/output/image_1_perturb_15.npy (deflated 4%)
# updating: content/output/image_4_perturb_39.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_12.npy (deflated 27%)
# updating: content/output/yehs_3_perturb_40.npy (deflated 29%)
# updating: content/output/ours_4_perturb_47.npy (deflated 6%)
# updating: content/output/image_2_perturb_23.npy (deflated 5%)
# updating: content/output/ours_4_perturb_21.npy (deflated 6%)
# updating: content/output/yehs_4_perturb_35.npy (deflated 26%)
# updating: content/output/image_1_perturb_26.npy (deflated 5%)
# updating: content/output/image_1_perturb_37.npy (deflated 5%)
# updating: content/output/ours_4_perturb_9.npy (deflated 7%)
# updating: content/output/yehs_1_perturb_46.npy (deflated 26%)
# updating: content/output/yehs_2_perturb_40.npy (deflated 24%)
# updating: content/output/yehs_3_perturb_9.npy (deflated 29%)
# updating: content/output/yehs_1_perturb_48.npy (deflated 27%)
# updating: content/output/ours_4_perturb_38.npy (deflated 6%)
# updating: content/output/yehs_3_perturb_3.npy (deflated 28%)
# updating: content/output/yehs_0_perturb_4.npy (deflated 27%)
# updating: content/output/ours_3_perturb_22.npy (deflated 7%)
# updating: content/output/image_3_perturb_20.npy (deflated 5%)
# updating: content/output/image_2_perturb_40.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_2.npy (deflated 24%)
# updating: content/output/image_3_perturb_10.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_11.npy (deflated 29%)
# updating: content/output/yehs_0_perturb_49.npy (deflated 23%)
# updating: content/output/ours_4_perturb_34.npy (deflated 6%)
# updating: content/output/yehs_2_perturb_35.npy (deflated 23%)
# updating: content/output/image_0_perturb_37.npy (deflated 5%)
# updating: content/output/image_4_perturb_15.npy (deflated 4%)
# updating: content/output/ours_1_perturb_0.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_45.npy (deflated 26%)
# updating: content/output/ours_3_perturb_25.npy (deflated 7%)
# updating: content/output/image_2_perturb_27.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_48.npy (deflated 25%)
# updating: content/output/yehs_0_perturb_18.npy (deflated 25%)
# updating: content/output/yehs_3_perturb_8.npy (deflated 29%)
# updating: content/output/image_2_perturb_44.npy (deflated 5%)
# updating: content/output/image_3_perturb_34.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_41.npy (deflated 27%)
# updating: content/output/image_3_perturb_0.npy (deflated 85%)
# updating: content/output/yehs_3_perturb_45.npy (deflated 29%)
# updating: content/output/yehs_0_perturb_6.npy (deflated 23%)
# updating: content/output/image_0_perturb_40.npy (deflated 5%)
# updating: content/output/image_3_perturb_13.npy (deflated 5%)
# updating: content/output/ours_1_perturb_22.npy (deflated 7%)
# updating: content/output/ours_3_perturb_12.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_0.npy (deflated 25%)
# updating: content/output/image_0_perturb_12.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_16.npy (deflated 27%)
# updating: content/output/image_3_perturb_35.npy (deflated 5%)
# updating: content/output/image_4_perturb_48.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_0.npy (deflated 25%)
# updating: content/output/ours_3_perturb_31.npy (deflated 7%)
# updating: content/output/ours_1_perturb_49.npy (deflated 7%)
# updating: content/output/ours_4_perturb_19.npy (deflated 6%)
# updating: content/output/ours_0_perturb_23.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_24.npy (deflated 29%)
# updating: content/output/ours_3_perturb_47.npy (deflated 7%)
# updating: content/output/image_3_perturb_47.npy (deflated 5%)
# updating: content/output/image_3_perturb_30.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_23.npy (deflated 25%)
# updating: content/output/ours_0_perturb_18.npy (deflated 8%)
# updating: content/output/yehs_2_perturb_39.npy (deflated 23%)
# updating: content/output/yehs_1_perturb_28.npy (deflated 27%)
# updating: content/output/ours_0_perturb_3.npy (deflated 7%)
# updating: content/output/image_2_perturb_46.npy (deflated 5%)
# updating: content/output/image_4_perturb_4.npy (deflated 5%)
# updating: content/output/image_4_perturb_44.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_23.npy (deflated 29%)
# updating: content/output/image_2_perturb_6.npy (deflated 5%)
# updating: content/output/image_3_perturb_23.npy (deflated 5%)
# updating: content/output/ours_1_perturb_25.npy (deflated 7%)
# updating: content/output/image_1_perturb_13.npy (deflated 5%)
# updating: content/output/ours_4_perturb_41.npy (deflated 6%)
# updating: content/output/ours_0_perturb_6.npy (deflated 7%)
# updating: content/output/ours_0_perturb_21.npy (deflated 7%)
# updating: content/output/ours_2_perturb_31.npy (deflated 7%)
# updating: content/output/image_1_perturb_20.npy (deflated 4%)
# updating: content/output/image_4_perturb_35.npy (deflated 5%)
# updating: content/output/image_2_perturb_16.npy (deflated 5%)
# updating: content/output/ours_0_perturb_27.npy (deflated 8%)
# updating: content/output/ours_1_perturb_1.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_34.npy (deflated 26%)
# updating: content/output/yehs_1_perturb_26.npy (deflated 27%)
# updating: content/output/image_4_perturb_0.npy (deflated 85%)
# updating: content/output/ours_1_perturb_12.npy (deflated 7%)
# updating: content/output/yehs_2_perturb_3.npy (deflated 24%)
# updating: content/output/ours_4_perturb_1.npy (deflated 7%)
# updating: content/output/image_0_perturb_25.npy (deflated 5%)
# updating: content/output/ours_0_perturb_45.npy (deflated 7%)
# updating: content/output/ours_1_perturb_19.npy (deflated 7%)
# updating: content/output/image_2_perturb_32.npy (deflated 5%)
# updating: content/output/image_1_perturb_44.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_26.npy (deflated 25%)
# updating: content/output/image_4_perturb_32.npy (deflated 5%)
# updating: content/output/image_1_perturb_49.npy (deflated 5%)
# updating: content/output/image_3_perturb_40.npy (deflated 5%)
# updating: content/output/image_3_perturb_1.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_40.npy (deflated 26%)
# updating: content/output/image_1_perturb_19.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_19.npy (deflated 24%)
# updating: content/output/image_0_perturb_2.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_42.npy (deflated 28%)
# updating: content/output/image_3_perturb_21.npy (deflated 4%)
# updating: content/output/image_0_perturb_8.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_19.npy (deflated 24%)
# updating: content/output/image_4_perturb_21.npy (deflated 5%)
# updating: content/output/image_4_perturb_43.npy (deflated 5%)
# updating: content/output/ours_3_perturb_20.npy (deflated 7%)
# updating: content/output/yehs_0_perturb_24.npy (deflated 22%)
# updating: content/output/ours_0_perturb_47.npy (deflated 7%)
# updating: content/output/image_3_perturb_41.npy (deflated 5%)
# updating: content/output/ours_0_perturb_28.npy (deflated 7%)
# updating: content/output/ours_0_perturb_9.npy (deflated 7%)
# updating: content/output/ours_0_perturb_32.npy (deflated 7%)
# updating: content/output/image_4_perturb_5.npy (deflated 5%)
# updating: content/output/image_4_perturb_38.npy (deflated 5%)
# updating: content/output/image_3_perturb_18.npy (deflated 5%)
# updating: content/output/image_2_perturb_33.npy (deflated 5%)
# updating: content/output/ours_0_perturb_17.npy (deflated 7%)
# updating: content/output/image_2_perturb_24.npy (deflated 4%)
# updating: content/output/image_0_perturb_13.npy (deflated 4%)
# updating: content/output/yehs_4_perturb_36.npy (deflated 27%)
# updating: content/output/yehs_1_perturb_41.npy (deflated 27%)
# updating: content/output/ours_3_perturb_46.npy (deflated 7%)
# updating: content/output/yehs_3_perturb_42.npy (deflated 29%)
# updating: content/output/image_0_perturb_4.npy (deflated 5%)
# updating: content/output/ours_2_perturb_17.npy (deflated 7%)
# updating: content/output/ours_1_perturb_20.npy (deflated 7%)
# updating: content/output/image_1_perturb_8.npy (deflated 5%)
# updating: content/output/image_3_perturb_2.npy (deflated 5%)
# updating: content/output/image_4_perturb_49.npy (deflated 5%)
# updating: content/output/image_1_perturb_17.npy (deflated 4%)
# updating: content/output/image_2_perturb_17.npy (deflated 5%)
# updating: content/output/image_4_perturb_14.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_37.npy (deflated 24%)
# updating: content/output/yehs_3_perturb_5.npy (deflated 29%)
# updating: content/output/yehs_0_perturb_41.npy (deflated 23%)
# updating: content/output/yehs_4_perturb_26.npy (deflated 26%)
# updating: content/output/ours_4_perturb_3.npy (deflated 7%)
# updating: content/output/image_2_perturb_31.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_14.npy (deflated 29%)
# updating: content/output/image_3_perturb_43.npy (deflated 5%)
# updating: content/output/image_0_perturb_7.npy (deflated 5%)
# updating: content/output/yehs_3_perturb_48.npy (deflated 29%)
# updating: content/output/yehs_1_perturb_37.npy (deflated 28%)
# updating: content/output/image_4_perturb_17.npy (deflated 5%)
# updating: content/output/ours_1_perturb_7.npy (deflated 7%)
# updating: content/output/ours_3_perturb_1.npy (deflated 7%)
# updating: content/output/image_1_perturb_14.npy (deflated 5%)
# updating: content/output/ours_1_perturb_8.npy (deflated 7%)
# updating: content/output/image_2_perturb_5.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_39.npy (deflated 25%)
# updating: content/output/ours_0_perturb_25.npy (deflated 7%)
# updating: content/output/image_3_perturb_4.npy (deflated 5%)
# updating: content/output/ours_0_perturb_46.npy (deflated 8%)
# updating: content/output/yehs_2_perturb_41.npy (deflated 24%)
# updating: content/output/image_4_perturb_3.npy (deflated 5%)
# updating: content/output/image_2_perturb_42.npy (deflated 5%)
# updating: content/output/ours_1_perturb_31.npy (deflated 7%)
# updating: content/output/ours_4_perturb_10.npy (deflated 6%)
# updating: content/output/image_4_perturb_37.npy (deflated 5%)
# updating: content/output/image_0_perturb_34.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_31.npy (deflated 28%)
# updating: content/output/ours_4_perturb_32.npy (deflated 6%)
# updating: content/output/image_3_perturb_11.npy (deflated 4%)
# updating: content/output/image_1_perturb_4.npy (deflated 5%)
# updating: content/output/yehs_4_perturb_12.npy (deflated 27%)
# updating: content/output/image_1_perturb_7.npy (deflated 5%)
# updating: content/output/image_2_perturb_36.npy (deflated 5%)
# updating: content/output/image_3_perturb_33.npy (deflated 5%)
# updating: content/output/yehs_0_perturb_37.npy (deflated 25%)
# updating: content/output/image_1_perturb_41.npy (deflated 5%)
# updating: content/output/yehs_2_perturb_29.npy (deflated 25%)
# updating: content/output/image_2_perturb_47.npy (deflated 5%)
# updating: content/output/image_2_perturb_48.npy (deflated 5%)
# updating: content/output/image_3_perturb_49.npy (deflated 5%)
# updating: content/output/image_0_perturb_17.npy (deflated 5%)
# updating: content/output/ours_4_perturb_16.npy (deflated 6%)
# updating: content/output/ours_4_perturb_0.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_8.npy (deflated 27%)
# updating: content/output/yehs_2_perturb_38.npy (deflated 23%)
# updating: content/output/ours_2_perturb_23.npy (deflated 7%)
# updating: content/output/yehs_4_perturb_49.npy (deflated 27%)
# updating: content/output/image_1_perturb_38.npy (deflated 5%)
# updating: content/output/yehs_1_perturb_15.npy (deflated 24%)

# %%
def visualize(metric="Infidelity", ours=results[0], yehs=results[1]):
  # Points for the x-axis
  points = ['p1', 'p2', 'p3', 'p4', 'p5']

  x = range(len(points))
  width = 0.35

  fig, ax = plt.subplots(figsize=(8, 5))
  bars1 = ax.bar(x, ours, width, label=f'Our {metric}', color="steelblue")
  bars2 = ax.bar([p + width for p in x], yehs, width, label=f"Yeh's {metric}", color="skyblue")

  # Add labels, title, and custom x-axis tick labels
  ax.set_xlabel('Points')
  ax.set_ylabel(f'{metric}')
  ax.set_title(f'{metric} Comparison at Different Points')
  ax.set_xticks([p + width / 2 for p in x])
  ax.set_xticklabels(points)
  ax.legend()

  plt.show()
  plt.savefig(f"{metric}_comparison_chart.png", dpi=300, bbox_inches="tight")
  plt.close(fig)

visualize("Infidelity", results[0], results[1])
visualize("Sensitivity", results[2], results[3])

# %%
fig, ax = plt.subplots(5, figsize=(5, 10))
for i in range(5):
  ax[i].imshow(np.load(f'output/image_{i}_perturb_0.npy'), cmap='gray', vmin=0, vmax=1)
  ax[i].set_axis_off()

# %%
fig, ax = plt.subplots(5, figsize=(5, 10))
for i in range(5):
  ax[i].imshow(np.load(f'output/yehs_{i}_perturb_0.npy'), cmap='RdBu_r', vmin=-0.01, vmax=0.01)
  ax[i].set_axis_off()

# %%
fig, ax = plt.subplots(5, figsize=(5, 10))
for i in range(5):
  ax[i].imshow(np.load(f'output/ours_{i}_perturb_0.npy'), cmap='RdBu_r', vmin=-0.01, vmax=0.01)
  ax[i].set_axis_off()
